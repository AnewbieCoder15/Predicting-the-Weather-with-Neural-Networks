# %% [markdown]
# Predicting the Weather with Neural Networks
# ===========================================

# %% [markdown]
# Example neural network

# %% [markdown]
# ![title](img/ANN_with_numbers.png)

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Read a CSV data file.

# %%
df = pd.read_csv('weatherPerth.csv')
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-07-01    Perth      2.7     18.8       0.0          0.8       9.1
# 1  2008-07-02    Perth      6.4     20.7       0.0          1.8       7.0
# 2  2008-07-03    Perth      6.5     19.9       0.4          2.2       7.3
# 3  2008-07-04    Perth      9.5     19.2       1.8          1.2       4.7
# 4  2008-07-05    Perth      9.5     16.4       1.8          1.4       4.9
# 5  2008-07-06    Perth      0.7     15.9       6.8          2.4       9.3
# 6  2008-07-07    Perth      0.7     18.3       0.0          0.8       9.3
# 7  2008-07-08    Perth      3.2     20.4       0.0          1.4       6.9
# 8  2008-07-09    Perth      9.8     19.5       8.0          1.2       2.5
# 9  2008-07-10    Perth     11.2     20.4       4.6          2.8       1.7
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0         ENE           20.0        NaN  ...        53.0       1027.6
# 1          NE           22.0        ESE  ...        39.0       1024.1
# 2          NE           31.0        NaN  ...        71.0       1016.8
# 3           W           26.0        NNE  ...        73.0       1019.3
# 4         WSW           44.0          W  ...        57.0       1020.4
# 5         NNE           24.0        ENE  ...        41.0       1032.0
# 6           N           37.0         NE  ...        36.0       1028.9
# 7         NNW           24.0         NE  ...        42.0       1023.9
# 8         ESE           31.0        NaN  ...        64.0       1026.4
# 9         NNW           46.0         NE  ...        50.0       1020.2
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1024.5       2.0       3.0      8.5     18.1         No      0.0
# 1       1019.0       0.0       6.0     11.1     19.7         No      0.4
# 2       1015.6       1.0       3.0     12.1     17.7         No      1.8
# 3       1018.4       6.0       6.0     13.2     17.7        Yes      1.8
# 4       1022.1       7.0       5.0     15.9     16.0        Yes      6.8
# 5       1029.6       0.0       1.0      6.9     15.5        Yes      0.0
# 6       1024.2       1.0       5.0      8.7     17.9         No      0.0
# 7       1021.1       6.0       5.0     10.2     19.3         No      8.0
# 8       1024.9       7.0       6.0     12.1     18.7        Yes      4.6
# 9       1014.0       7.0       7.0     13.4     19.0        Yes      2.6
#
#    RainTomorrow
# 0            No
# 1            No
# 2           Yes
# 3           Yes
# 4           Yes
# 5            No
# 6            No
# 7           Yes
# 8           Yes
# 9           Yes
#
# [10 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3193 non-null   object
#  1   Location       3193 non-null   object
#  2   MinTemp        3193 non-null   float64
#  3   MaxTemp        3192 non-null   float64
#  4   Rainfall       3193 non-null   float64
#  5   Evaporation    3192 non-null   float64
#  6   Sunshine       3188 non-null   float64
#  7   WindGustDir    3188 non-null   object
#  8   WindGustSpeed  3188 non-null   float64
#  9   WindDir9am     3059 non-null   object
#  10  WindDir3pm     3186 non-null   object
#  11  WindSpeed9am   3193 non-null   int64
#  12  WindSpeed3pm   3192 non-null   float64
#  13  Humidity9am    3184 non-null   float64
#  14  Humidity3pm    3185 non-null   float64
#  15  Pressure9am    3192 non-null   float64
#  16  Pressure3pm    3192 non-null   float64
#  17  Cloud9am       3191 non-null   float64
#  18  Cloud3pm       3189 non-null   float64
#  19  Temp9am        3193 non-null   float64
#  20  Temp3pm        3192 non-null   float64
#  21  RainToday      3193 non-null   object
#  22  RISK_MM        3193 non-null   float64
#  23  RainTomorrow   3193 non-null   object
# dtypes: float64(16), int64(1), object(7)
# memory usage: 598.8+ KB

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            1
# Rainfall           0
# Evaporation        1
# Sunshine           5
# WindGustDir        5
# WindGustSpeed      5
# WindDir9am       134
# WindDir3pm         7
# WindSpeed9am       0
# WindSpeed3pm       1
# Humidity9am        9
# Humidity3pm        8
# Pressure9am        1
# Pressure3pm        1
# Cloud9am           2
# Cloud3pm           4
# Temp9am            0
# Temp3pm            1
# RainToday          0
# RISK_MM            0
# RainTomorrow       0
# dtype: int64

# %% [markdown]
# Pre-process the data.  First, remove unwanted variables.

# %%
exclude = ['Date', 'RISK_MM', 'Location']
df.drop(exclude,axis=1,inplace=True)

# %%
df.shape
# Out:
# (3193, 21)

# %% [markdown]
# Dealing with missing values.

# %%
df=df.dropna()

# %% [markdown]
# Boolean variables to 0s and 1s.

# %%
bools = ['RainToday', 'RainTomorrow']
for col in bools:
    df[col]=df[col].map({
        'Yes':1,
        'No':0
    })

# %%
df
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1         6.4     20.7       0.0          1.8       7.0          NE
# 3         9.5     19.2       1.8          1.2       4.7           W
# 4         9.5     16.4       1.8          1.4       4.9         WSW
# 5         0.7     15.9       6.8          2.4       9.3         NNE
# 6         0.7     18.3       0.0          0.8       9.3           N
# ...       ...      ...       ...          ...       ...         ...
# 3188     10.3     19.9       0.2          1.8       7.5          NW
# 3189     13.0     16.8      61.2          3.6       0.0         SSW
# 3190     13.3     18.9       0.4          1.8       6.5          SE
# 3191     11.5     18.2       0.0          3.8       9.3          SE
# 3192      6.3     17.0       0.0          1.6       7.9           E
#
#       WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 1              22.0        ESE        ENE             6  ...         80.0
# 3              26.0        NNE        NNW            11  ...         93.0
# 4              44.0          W         SW            13  ...         69.0
# 5              24.0        ENE         NE             4  ...         86.0
# 6              37.0         NE        NNE            15  ...         72.0
# ...             ...        ...        ...           ...  ...          ...
# 3188           37.0        NNE        NNW             9  ...         89.0
# 3189           46.0          W         SW            17  ...         90.0
# 3190           37.0         SE        ESE            11  ...         85.0
# 3191           30.0        ESE        ESE             9  ...         62.0
# 3192           26.0         SE         SE             4  ...         75.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 1            39.0       1024.1       1019.0       0.0       6.0     11.1
# 3            73.0       1019.3       1018.4       6.0       6.0     13.2
# 4            57.0       1020.4       1022.1       7.0       5.0     15.9
# 5            41.0       1032.0       1029.6       0.0       1.0      6.9
# 6            36.0       1028.9       1024.2       1.0       5.0      8.7
# ...           ...          ...          ...       ...       ...      ...
# 3188         60.0       1017.1       1013.8       5.0       6.0     13.0
# 3189         75.0       1005.6       1008.9       7.0       7.0     16.4
# 3190         65.0       1019.2       1019.4       6.0       6.0     15.1
# 3191         47.0       1025.9       1023.4       1.0       3.0     14.0
# 3192         49.0       1028.6       1026.0       1.0       3.0     11.5
#
#       Temp3pm  RainToday  RainTomorrow
# 1        19.7          0             0
# 3        17.7          1             1
# 4        16.0          1             1
# 5        15.5          1             0
# 6        17.9          0             0
# ...       ...        ...           ...
# 3188     18.5          0             1
# 3189     15.6          1             0
# 3190     18.0          0             0
# 3191     17.6          0             0
# 3192     15.6          0             0
#
# [3025 rows x 21 columns]

# %% [markdown]
# Cyclical attributes
#
# ![title](img/cardinal.png)

# %% [markdown]
# Map Cardinal Direction to Radians

# %%
dirs = ['N','NNE','NE','ENE','E','ESE','SE','SSE','S','SSW','SW','WSW','W','WNW','NW','NNW']
angles = np.arange(0.0, 2.0*np.pi, 2.0*np.pi / 16.0)
wind_angles = dict(zip(dirs, angles))
print(wind_angles)
# Out:
# {'N': 0.0, 'NNE': 0.39269908169872414, 'NE': 0.7853981633974483, 'ENE': 1.1780972450961724, 'E': 1.5707963267948966, 'ESE': 1.9634954084936207, 'SE': 2.356194490192345, 'SSE': 2.748893571891069, 'S': 3.141592653589793, 'SSW': 3.5342917352885173, 'SW': 3.9269908169872414, 'WSW': 4.319689898685965, 'W': 4.71238898038469, 'WNW': 5.105088062083414, 'NW': 5.497787143782138, 'NNW': 5.890486225480862}

# %% [markdown]
# Replace cyclical attributes with sin() and cos()

# %%
wind_attributes = ['WindGustDir', 'WindDir9am', 'WindDir3pm']
for col in wind_attributes:
    df[col] = df[col].map(wind_angles)
    df[col+'_cos']=np.cos(df[col])
    df[col+'_sin']=np.sin(df[col])
    df = df.drop(col,axis=1)

# %%
df.head(10)
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 1       6.4     20.7       0.0          1.8       7.0           22.0
# 3       9.5     19.2       1.8          1.2       4.7           26.0
# 4       9.5     16.4       1.8          1.4       4.9           44.0
# 5       0.7     15.9       6.8          2.4       9.3           24.0
# 6       0.7     18.3       0.0          0.8       9.3           37.0
# 7       3.2     20.4       0.0          1.4       6.9           24.0
# 9      11.2     20.4       4.6          2.8       1.7           46.0
# 10     13.4     17.1       2.6          2.6       4.2           54.0
# 11      7.9     17.3       4.4          2.2       5.4           19.0
# 12      5.3     18.8       0.2          1.0       2.3           17.0
#
#     WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Temp9am  \
# 1              6           9.0         80.0         39.0  ...     11.1
# 3             11           6.0         93.0         73.0  ...     13.2
# 4             13          17.0         69.0         57.0  ...     15.9
# 5              4           7.0         86.0         41.0  ...      6.9
# 6             15          13.0         72.0         36.0  ...      8.7
# 7              9          13.0         58.0         42.0  ...     10.2
# 9             19          11.0         79.0         50.0  ...     13.4
# 10            26          13.0         63.0         77.0  ...     15.4
# 11             7           9.0         99.0         59.0  ...      9.6
# 12             7           7.0         96.0         63.0  ...      9.5
#
#     Temp3pm  RainToday  RainTomorrow  WindGustDir_cos  WindGustDir_sin  \
# 1      19.7          0             0     7.071068e-01         0.707107
# 3      17.7          1             1    -1.836970e-16        -1.000000
# 4      16.0          1             1    -3.826834e-01        -0.923880
# 5      15.5          1             0     9.238795e-01         0.382683
# 6      17.9          0             0     1.000000e+00         0.000000
# 7      19.3          0             1     9.238795e-01        -0.382683
# 9      19.0          1             1     9.238795e-01        -0.382683
# 10     14.8          1             1    -7.071068e-01        -0.707107
# 11     16.2          1             0    -9.238795e-01        -0.382683
# 12     17.2          0             0     1.000000e+00         0.000000
#
#     WindDir9am_cos  WindDir9am_sin  WindDir3pm_cos  WindDir3pm_sin
# 1    -3.826834e-01        0.923880    3.826834e-01        0.923880
# 3     9.238795e-01        0.382683    9.238795e-01       -0.382683
# 4    -1.836970e-16       -1.000000   -7.071068e-01       -0.707107
# 5     3.826834e-01        0.923880    7.071068e-01        0.707107
# 6     7.071068e-01        0.707107    9.238795e-01        0.382683
# 7     7.071068e-01        0.707107    1.000000e+00        0.000000
# 9     7.071068e-01        0.707107    9.238795e-01        0.382683
# 10   -7.071068e-01       -0.707107   -7.071068e-01       -0.707107
# 11    1.000000e+00        0.000000   -9.238795e-01       -0.382683
# 12    7.071068e-01        0.707107   -1.836970e-16       -1.000000
#
# [10 rows x 24 columns]

# %% [markdown]
# Extract attributes (X) and class labels (y).

# %%
y = df['RainTomorrow']
X = df.drop('RainTomorrow',axis=1)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 1      6.4     20.7       0.0          1.8       7.0           22.0
# 3      9.5     19.2       1.8          1.2       4.7           26.0
# 4      9.5     16.4       1.8          1.4       4.9           44.0
# 5      0.7     15.9       6.8          2.4       9.3           24.0
# 6      0.7     18.3       0.0          0.8       9.3           37.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Cloud3pm  \
# 1             6           9.0         80.0         39.0  ...       6.0
# 3            11           6.0         93.0         73.0  ...       6.0
# 4            13          17.0         69.0         57.0  ...       5.0
# 5             4           7.0         86.0         41.0  ...       1.0
# 6            15          13.0         72.0         36.0  ...       5.0
#
#    Temp9am  Temp3pm  RainToday  WindGustDir_cos  WindGustDir_sin  \
# 1     11.1     19.7          0     7.071068e-01         0.707107
# 3     13.2     17.7          1    -1.836970e-16        -1.000000
# 4     15.9     16.0          1    -3.826834e-01        -0.923880
# 5      6.9     15.5          1     9.238795e-01         0.382683
# 6      8.7     17.9          0     1.000000e+00         0.000000
#
#    WindDir9am_cos  WindDir9am_sin  WindDir3pm_cos  WindDir3pm_sin
# 1   -3.826834e-01        0.923880        0.382683        0.923880
# 3    9.238795e-01        0.382683        0.923880       -0.382683
# 4   -1.836970e-16       -1.000000       -0.707107       -0.707107
# 5    3.826834e-01        0.923880        0.707107        0.707107
# 6    7.071068e-01        0.707107        0.923880        0.382683
#
# [5 rows x 23 columns]

# %% [markdown]
# Split dataset into training and testing subsets.

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=0)

print('X_train : ',X_train.shape)
print('X_test : ',X_test.shape)
print('y_train : ',y_train.shape)
print('y_test : ',y_test.shape)
# Out:
# X_train :  (2026, 23)
# X_test :  (999, 23)
# y_train :  (2026,)
# y_test :  (999,)

# %% [markdown]
# Scale.

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Instantiate a neural network and train it.
#
# ![title](img/ANN_2_layers.png)

# %% [markdown]
# Input layer size.

# %%
X_train.shape
# Out:
# (2026, 23)

# %% [markdown]
# Instantiate a neural network and train it.

# %%
model = MLPClassifier(
    hidden_layer_sizes=(50,50),
    random_state=0,
    max_iter=500,
)
model.fit(X_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(50, 50), max_iter=500, random_state=0)

# %% [markdown]
# Predict target class for the testing set.

# %%
y_pred = model.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7927927927927928

# %% [markdown]
# Search for best network layout.

# %%
p ={
    'hidden_layer_sizes':((2,),(5,),(10,),(10,10),(20,40),(30,30,30))
}
model = MLPClassifier(
    max_iter=3000,
    random_state=0,
)
gs = GridSearchCV(model,p,cv=6)
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=6, estimator=MLPClassifier(max_iter=3000, random_state=0),
#              param_grid={'hidden_layer_sizes': ((2,), (5,), (10,), (10, 10),
#                                                 (20, 40), (30, 30, 30))})

# %% [markdown]
# Display grid search results.

# %%
print(gs.cv_results_['params'])
print(gs.cv_results_['mean_test_score'])
# Out:
# [{'hidden_layer_sizes': (2,)}, {'hidden_layer_sizes': (5,)}, {'hidden_layer_sizes': (10,)}, {'hidden_layer_sizes': (10, 10)}, {'hidden_layer_sizes': (20, 40)}, {'hidden_layer_sizes': (30, 30, 30)}]
# [0.90424707 0.90621068 0.89287951 0.88992093 0.87561527 0.88054331]

# %% [markdown]
# Predictions using the best neural network.

# %%
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7927927927927928
